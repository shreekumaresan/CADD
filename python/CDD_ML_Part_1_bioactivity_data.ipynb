# %% [markdown]
# # **Computational Drug Discovery [Part 1] Download Bioactivity Data**
#
# Chanin Nantasenamat
#
# [*'Data Professor' YouTube channel*](http://youtube.com/dataprofessor)
#
# In this Jupyter notebook, we will be building a real-life **data science project** that you can include in your **data science portfolio**. Particularly, we will be building a machine learning model using the ChEMBL bioactivity data.
#
# ---

# %% [markdown]
# ## **ChEMBL Database**
#
# The [*ChEMBL Database*](https://www.ebi.ac.uk/chembl/) is a database that contains curated bioactivity data of more than 2 million compounds. It is compiled from more than 76,000 documents, 1.2 million assays and the data spans 13,000 targets and 1,800 cells and 33,000 indications.
# [Data as of March 25, 2020; ChEMBL version 26].

# %% [markdown]
# ## **Installing libraries**

# %% [markdown]
# Install the ChEMBL web service package so that we can retrieve bioactivity data from the ChEMBL Database.

# %%
! pip install chembl_webresource_client
# Out:
# Collecting chembl_webresource_client
#   Downloading chembl_webresource_client-0.10.9-py3-none-any.whl.metadata (1.4 kB)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.10/dist-packages (from chembl_webresource_client) (2.2.3)
# Requirement already satisfied: requests>=2.18.4 in /usr/local/lib/python3.10/dist-packages (from chembl_webresource_client) (2.32.3)
# Collecting requests-cache~=1.2 (from chembl_webresource_client)
#   Downloading requests_cache-1.2.1-py3-none-any.whl.metadata (9.9 kB)
# Requirement already satisfied: easydict in /usr/local/lib/python3.10/dist-packages (from chembl_webresource_client) (1.13)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.18.4->chembl_webresource_client) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.18.4->chembl_webresource_client) (3.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.18.4->chembl_webresource_client) (2024.12.14)
# Requirement already satisfied: attrs>=21.2 in /usr/local/lib/python3.10/dist-packages (from requests-cache~=1.2->chembl_webresource_client) (24.3.0)
# Collecting cattrs>=22.2 (from requests-cache~=1.2->chembl_webresource_client)
#   Downloading cattrs-24.1.2-py3-none-any.whl.metadata (8.4 kB)
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests-cache~=1.2->chembl_webresource_client) (4.3.6)
# Collecting url-normalize>=1.4 (from requests-cache~=1.2->chembl_webresource_client)
#   Downloading url_normalize-1.4.3-py2.py3-none-any.whl.metadata (3.1 kB)
# Requirement already satisfied: exceptiongroup>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from cattrs>=22.2->requests-cache~=1.2->chembl_webresource_client) (1.2.2)
# Requirement already satisfied: typing-extensions!=4.6.3,>=4.1.0 in /usr/local/lib/python3.10/dist-packages (from cattrs>=22.2->requests-cache~=1.2->chembl_webresource_client) (4.12.2)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from url-normalize>=1.4->requests-cache~=1.2->chembl_webresource_client) (1.17.0)
# Downloading chembl_webresource_client-0.10.9-py3-none-any.whl (55 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.2/55.2 kB 2.4 MB/s eta 0:00:00
# Downloading requests_cache-1.2.1-py3-none-any.whl (61 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.4/61.4 kB 4.9 MB/s eta 0:00:00
# Downloading cattrs-24.1.2-py3-none-any.whl (66 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.4/66.4 kB 6.0 MB/s eta 0:00:00
# Downloading url_normalize-1.4.3-py2.py3-none-any.whl (6.8 kB)
# Installing collected packages: url-normalize, cattrs, requests-cache, chembl_webresource_client
# Successfully installed cattrs-24.1.2 chembl_webresource_client-0.10.9 requests-cache-1.2.1 url-normalize-1.4.3

# %% [markdown]
# ## **Importing libraries**

# %%
# Import necessary libraries
import pandas as pd
from chembl_webresource_client.new_client import new_client

# %% [markdown]
# ## **Search for Target protein**

# %% [markdown]
# ### **Target search for coronavirus**

# %%
# Target search for coronavirus
target = new_client.target
target_query = target.search('EGFR')
targets = pd.DataFrame.from_dict(target_query)
targets
# Out:
#    cross_references           organism  \
# 0                []       Mus musculus
# 1                []       Homo sapiens
# 2                []       Homo sapiens
# 3                []       Homo sapiens
# 4                []       Homo sapiens
# 5                []       Homo sapiens
# 6                []       Homo sapiens
# 7                []       Homo sapiens
# 8                []       Homo sapiens
# 9                []       Homo sapiens
# 10               []       Homo sapiens
# 11               []  Rattus norvegicus
# 12               []       Homo sapiens
# 13               []       Homo sapiens
# 14               []       Mus musculus
# 15               []       Homo sapiens
# 16               []       Homo sapiens
# 17               []       Homo sapiens
#
#                                             pref_name  score  \
# 0              Epidermal growth factor receptor erbB1   16.0
# 1                                         EGFR/PPP1CA   16.0
# 2                                            VHL/EGFR   16.0
# 3                                           CCN2-EGFR   16.0
# 4              Epidermal growth factor receptor erbB1   12.0
# 5   Protein cereblon/Epidermal growth factor receptor   12.0
# 6                    Epidermal growth factor receptor   11.0
# 7   Epidermal growth factor receptor and ErbB2 (HE...   10.0
# 8   MER intracellular domain/EGFR extracellular do...   10.0
# 9                           ErbB-2/ErbB-3 heterodimer   10.0
# 10            Receptor protein-tyrosine kinase erbB-2    9.0
# 11            Receptor protein-tyrosine kinase erbB-2    9.0
# 12            Receptor protein-tyrosine kinase erbB-4    9.0
# 13            Receptor tyrosine-protein kinase erbB-3    9.0
# 14            Receptor tyrosine-protein kinase erbB-2    9.0
# 15                                          FASN/HER2    9.0
# 16  Baculoviral IAP repeat-containing protein 2/Ep...    9.0
# 17        VHL/Receptor protein-tyrosine kinase erbB-2    9.0
#
#     species_group_flag target_chembl_id  \
# 0                False       CHEMBL3608
# 1                False    CHEMBL4523747
# 2                False    CHEMBL4523998
# 3                False    CHEMBL5465557
# 4                False        CHEMBL203
# 5                False    CHEMBL4523680
# 6                False    CHEMBL2363049
# 7                False    CHEMBL2111431
# 8                False    CHEMBL3137284
# 9                False    CHEMBL4630723
# 10               False       CHEMBL1824
# 11               False       CHEMBL3848
# 12               False       CHEMBL3009
# 13               False       CHEMBL5838
# 14               False    CHEMBL2311234
# 15               False    CHEMBL4106134
# 16               False    CHEMBL4802031
# 17               False    CHEMBL5465227
#
#                                     target_components  \
# 0   [{'accession': 'Q01279', 'component_descriptio...
# 1   [{'accession': 'P00533', 'component_descriptio...
# 2   [{'accession': 'P00533', 'component_descriptio...
# 3   [{'accession': 'P00533', 'component_descriptio...
# 4   [{'accession': 'P00533', 'component_descriptio...
# 5   [{'accession': 'P00533', 'component_descriptio...
# 6   [{'accession': 'P04626', 'component_descriptio...
# 7   [{'accession': 'P04626', 'component_descriptio...
# 8   [{'accession': 'P00533', 'component_descriptio...
# 9   [{'accession': 'P04626', 'component_descriptio...
# 10  [{'accession': 'P04626', 'component_descriptio...
# 11  [{'accession': 'P06494', 'component_descriptio...
# 12  [{'accession': 'Q15303', 'component_descriptio...
# 13  [{'accession': 'P21860', 'component_descriptio...
# 14  [{'accession': 'P70424', 'component_descriptio...
# 15  [{'accession': 'P04626', 'component_descriptio...
# 16  [{'accession': 'P00533', 'component_descriptio...
# 17  [{'accession': 'P04626', 'component_descriptio...
#
#                     target_type  tax_id
# 0                SINGLE PROTEIN   10090
# 1   PROTEIN-PROTEIN INTERACTION    9606
# 2   PROTEIN-PROTEIN INTERACTION    9606
# 3   PROTEIN-PROTEIN INTERACTION    9606
# 4                SINGLE PROTEIN    9606
# 5   PROTEIN-PROTEIN INTERACTION    9606
# 6                PROTEIN FAMILY    9606
# 7                PROTEIN FAMILY    9606
# 8              CHIMERIC PROTEIN    9606
# 9               PROTEIN COMPLEX    9606
# 10               SINGLE PROTEIN    9606
# 11               SINGLE PROTEIN   10116
# 12               SINGLE PROTEIN    9606
# 13               SINGLE PROTEIN    9606
# 14               SINGLE PROTEIN   10090
# 15              PROTEIN COMPLEX    9606
# 16  PROTEIN-PROTEIN INTERACTION    9606
# 17  PROTEIN-PROTEIN INTERACTION    9606

# %% [markdown]
# ### **Select and retrieve bioactivity data for *SARS coronavirus 3C-like proteinase* (fifth entry)**

# %% [markdown]
# We will assign the fifth entry (which corresponds to the target protein, *coronavirus 3C-like proteinase*) to the ***selected_target*** variable

# %%
selected_target = targets.target_chembl_id[4]
selected_target
# Out:
# 'CHEMBL203'

# %% [markdown]
# Here, we will retrieve only bioactivity data for *coronavirus 3C-like proteinase* (CHEMBL3927) that are reported as IC$_{50}$ values in nM (nanomolar) unit.

# %%
activity = new_client.activity
res = activity.filter(target_chembl_id=selected_target).filter(standard_type="IC50")

# %%
df = pd.DataFrame.from_dict(res)

# %%
len(df)
# Out:
# 18105

# %%
df.head(3)
# Out:
#   action_type activity_comment  activity_id activity_properties  \
# 0        None             None        32260                  []
# 1        None             None        32263                  []
# 2        None             None        32265                  []
#
#   assay_chembl_id                                  assay_description  \
# 0    CHEMBL674637  Inhibitory activity towards tyrosine phosphory...
# 1    CHEMBL621151  Inhibition of autophosphorylation of human epi...
# 2    CHEMBL615325  Inhibition of ligand-induced proliferation in ...
#
#   assay_type assay_variant_accession assay_variant_mutation bao_endpoint  ...  \
# 0          B                    None                   None  BAO_0000190  ...
# 1          F                    None                   None  BAO_0000190  ...
# 2          F                    None                   None  BAO_0000190  ...
#
#   target_organism                        target_pref_name target_tax_id  \
# 0    Homo sapiens  Epidermal growth factor receptor erbB1          9606
# 1    Homo sapiens  Epidermal growth factor receptor erbB1          9606
# 2    Homo sapiens  Epidermal growth factor receptor erbB1          9606
#
#   text_value  toid  type units    uo_units upper_value  value
# 0       None  None  IC50    uM  UO_0000065        None  0.041
# 1       None  None  IC50    uM  UO_0000065        None    0.3
# 2       None  None  IC50    uM  UO_0000065        None   7.82
#
# [3 rows x 46 columns]

# %%
df.standard_type.unique()
# Out:
# array(['IC50'], dtype=object)

# %% [markdown]
# Finally we will save the resulting bioactivity data to a CSV file **bioactivity_data.csv**.

# %%
df.to_csv('bioactivity_data.csv', index=False)

# %% [markdown]
# ## **Copying files to Google Drive**

# %% [markdown]
# Firstly, we need to mount the Google Drive into Colab so that we can have access to our Google adrive from within Colab.

# %%
from google.colab import drive
drive.mount('/content/gdrive/', force_remount=True)
# Out:
# Mounted at /content/gdrive/

# %% [markdown]
# Next, we create a **data** folder in our **Colab Notebooks** folder on Google Drive.

# %%
! mkdir "/content/gdrive/My Drive/ScienceFair/DrugDesign/Colab"
# Out:
# mkdir: cannot create directory ‘/content/gdrive/My Drive/ScienceFair/DrugDesign/Colab’: File exists

# %%
! cp bioactivity_data.csv "/content/gdrive/My Drive/ScienceFair/DrugDesign/Colab"

# %%
! ls -l "/content/gdrive/My Drive/ScienceFair/DrugDesign/Colab"
# Out:
# total 12419
# -rw------- 1 root root 11443244 Jan  5 19:31 bioactivity_data.csv
# -rw------- 1 root root  1273329 Jan  5 20:11 bioactivity_data_preprocessed.csv

# %% [markdown]
# Let's see the CSV files that we have so far.

# %%
! ls
# Out:
# bioactivity_data.csv  gdrive  sample_data

# %% [markdown]
# Taking a glimpse of the **bioactivity_data.csv** file that we've just created.

# %%
import pandas as pd
df = pd.read_csv('bioactivity_data.csv')

# %%
! head bioactivity_data.csv
# Out:
# action_type,activity_comment,activity_id,activity_properties,assay_chembl_id,assay_description,assay_type,assay_variant_accession,assay_variant_mutation,bao_endpoint,bao_format,bao_label,canonical_smiles,data_validity_comment,data_validity_description,document_chembl_id,document_journal,document_year,ligand_efficiency,molecule_chembl_id,molecule_pref_name,parent_molecule_chembl_id,pchembl_value,potential_duplicate,qudt_units,record_id,relation,src_id,standard_flag,standard_relation,standard_text_value,standard_type,standard_units,standard_upper_value,standard_value,target_chembl_id,target_organism,target_pref_name,target_tax_id,text_value,toid,type,units,uo_units,upper_value,value
# ,,32260,[],CHEMBL674637,Inhibitory activity towards tyrosine phosphorylation for the epidermal growth factor-receptor kinase,B,,,BAO_0000190,BAO_0000357,single protein format,Cc1cc(C)c(/C=C2\C(=O)Nc3ncnc(Nc4ccc(F)c(Cl)c4)c32)[nH]1,,,CHEMBL1134862,Bioorg Med Chem Lett,2002.0,"{'bei': '19.25', 'le': '0.37', 'lle': '2.94', 'sei': '8.93'}",CHEMBL68920,,CHEMBL68920,7.39,0,http://www.openphacts.org/units/Nanomolar,119482,=,1,1,=,,IC50,nM,,41.0,CHEMBL203,Homo sapiens,Epidermal growth factor receptor erbB1,9606,,,IC50,uM,UO_0000065,,0.041
# ,,32263,[],CHEMBL621151,Inhibition of autophosphorylation of human epidermal growth factor-receptor (EGF-R) expressed in A431 cells,F,,,BAO_0000190,BAO_0000219,cell-based format,Cc1cc(C)c(/C=C2\C(=O)Nc3ncnc(Nc4ccc(F)c(Cl)c4)c32)[nH]1,,,CHEMBL1134862,Bioorg Med Chem Lett,2002.0,,CHEMBL68920,,CHEMBL68920,6.52,0,http://www.openphacts.org/units/Nanomolar,119482,=,1,1,=,,IC50,nM,,300.0,CHEMBL203,Homo sapiens,Epidermal growth factor receptor erbB1,9606,,,IC50,uM,UO_0000065,,0.3
# ,,32265,[],CHEMBL615325,Inhibition of ligand-induced proliferation in human EGF-R Kinase expressing 3T3 cells,F,,,BAO_0000190,BAO_0000219,cell-based format,Cc1cc(C)c(/C=C2\C(=O)Nc3ncnc(Nc4ccc(F)c(Cl)c4)c32)[nH]1,,,CHEMBL1134862,Bioorg Med Chem Lett,2002.0,,CHEMBL68920,,CHEMBL68920,5.11,0,http://www.openphacts.org/units/Nanomolar,119482,=,1,1,=,,IC50,nM,,7820.0,CHEMBL203,Homo sapiens,Epidermal growth factor receptor erbB1,9606,,,IC50,uM,UO_0000065,,7.82
# ,,32267,[],CHEMBL674637,Inhibitory activity towards tyrosine phosphorylation for the epidermal growth factor-receptor kinase,B,,,BAO_0000190,BAO_0000357,single protein format,Cc1cc(C(=O)N2CCOCC2)[nH]c1/C=C1\C(=O)Nc2ncnc(Nc3ccc(F)c(Cl)c3)c21,,,CHEMBL1134862,Bioorg Med Chem Lett,2002.0,"{'bei': '14.02', 'le': '0.27', 'lle': '3.16', 'sei': '6.03'}",CHEMBL69960,,CHEMBL69960,6.77,0,http://www.openphacts.org/units/Nanomolar,119494,=,1,1,=,,IC50,nM,,170.0,CHEMBL203,Homo sapiens,Epidermal growth factor receptor erbB1,9606,,,IC50,uM,UO_0000065,,0.17
# ,,32270,[],CHEMBL621151,Inhibition of autophosphorylation of human epidermal growth factor-receptor (EGF-R) expressed in A431 cells,F,,,BAO_0000190,BAO_0000219,cell-based format,Cc1cc(C(=O)N2CCOCC2)[nH]c1/C=C1\C(=O)Nc2ncnc(Nc3ccc(F)c(Cl)c3)c21,,,CHEMBL1134862,Bioorg Med Chem Lett,2002.0,,CHEMBL69960,,CHEMBL69960,7.40,0,http://www.openphacts.org/units/Nanomolar,119494,=,1,1,=,,IC50,nM,,40.0,CHEMBL203,Homo sapiens,Epidermal growth factor receptor erbB1,9606,,,IC50,uM,UO_0000065,,0.04
# ,,32272,[],CHEMBL615325,Inhibition of ligand-induced proliferation in human EGF-R Kinase expressing 3T3 cells,F,,,BAO_0000190,BAO_0000219,cell-based format,Cc1cc(C(=O)N2CCOCC2)[nH]c1/C=C1\C(=O)Nc2ncnc(Nc3ccc(F)c(Cl)c3)c21,,,CHEMBL1134862,Bioorg Med Chem Lett,2002.0,,CHEMBL69960,,CHEMBL69960,6.36,0,http://www.openphacts.org/units/Nanomolar,119494,=,1,1,=,,IC50,nM,,440.0,CHEMBL203,Homo sapiens,Epidermal growth factor receptor erbB1,9606,,,IC50,uM,UO_0000065,,0.44
# ,,32680,[],CHEMBL677833,In vitro inhibition of Epidermal growth factor receptor tyrosine kinase isolated from A431 (human carcinoma).,B,,,BAO_0000190,BAO_0000357,single protein format,CN(c1ccccc1)c1ncnc2ccc(N/N=N/Cc3ccccn3)cc12,,,CHEMBL1145114,J Med Chem,2003.0,"{'bei': '13.62', 'le': '0.25', 'lle': '0.26', 'sei': '6.40'}",CHEMBL137635,,CHEMBL137635,5.03,0,http://www.openphacts.org/units/Nanomolar,262238,=,1,1,=,,IC50,nM,,9300.0,CHEMBL203,Homo sapiens,Epidermal growth factor receptor erbB1,9606,,,IC50,uM,UO_0000065,,9.3
# ,,32770,[],CHEMBL674643,Inhibitory concentration of EGF dependent autophosphorylation of epidermal growth factor receptor kinase,B,,,BAO_0000190,BAO_0000357,single protein format,CC(=C(C#N)C#N)c1ccc(NC(=O)CCC(=O)O)cc1,Outside typical range,"Values for this activity type are unusually large/small, so may not be accurate",CHEMBL1124610,J Med Chem,1989.0,,CHEMBL306988,,CHEMBL306988,,0,http://www.openphacts.org/units/Nanomolar,137177,=,1,1,=,,IC50,nM,,500000.0,CHEMBL203,Homo sapiens,Epidermal growth factor receptor erbB1,9606,,,IC50,uM,UO_0000065,,500.0
# ,,32772,[],CHEMBL674643,Inhibitory concentration of EGF dependent autophosphorylation of epidermal growth factor receptor kinase,B,,,BAO_0000190,BAO_0000357,single protein format,O=C(O)/C=C/c1ccc(O)cc1,Outside typical range,"Values for this activity type are unusually large/small, so may not be accurate",CHEMBL1124610,J Med Chem,1989.0,,CHEMBL66879,COUMARIC ACID,CHEMBL66879,,0,http://www.openphacts.org/units/Nanomolar,137215,=,1,1,=,,IC50,nM,,3000000.0,CHEMBL203,Homo sapiens,Epidermal growth factor receptor erbB1,9606,,,IC50,uM,UO_0000065,,3000.0

# %% [markdown]
# ## **Handling missing data**
# If any compounds has missing value for the **standard_value** column then drop it

# %%
df2 = df[df.standard_value.notna()]
df2
# Out:
#       action_type activity_comment  activity_id  \
# 0             NaN              NaN        32260
# 1             NaN              NaN        32263
# 2             NaN              NaN        32265
# 3             NaN              NaN        32267
# 4             NaN              NaN        32270
# ...           ...              ...          ...
# 18100         NaN              NaN     25785193
# 18101         NaN              NaN     25785838
# 18102         NaN              NaN     25786818
# 18103         NaN              NaN     25787599
# 18104         NaN              NaN     25789586
#
#                                      activity_properties assay_chembl_id  \
# 0                                                     []    CHEMBL674637
# 1                                                     []    CHEMBL621151
# 2                                                     []    CHEMBL615325
# 3                                                     []    CHEMBL674637
# 4                                                     []    CHEMBL621151
# ...                                                  ...             ...
# 18100  [{'comments': None, 'relation': '=', 'result_f...   CHEMBL5471956
# 18101  [{'comments': None, 'relation': '=', 'result_f...   CHEMBL5472624
# 18102  [{'comments': None, 'relation': None, 'result_...   CHEMBL5473647
# 18103  [{'comments': None, 'relation': None, 'result_...   CHEMBL5474412
# 18104  [{'comments': None, 'relation': None, 'result_...   CHEMBL5481337
#
#                                        assay_description assay_type  \
# 0      Inhibitory activity towards tyrosine phosphory...          B
# 1      Inhibition of autophosphorylation of human epi...          F
# 2      Inhibition of ligand-induced proliferation in ...          F
# 3      Inhibitory activity towards tyrosine phosphory...          B
# 4      Inhibition of autophosphorylation of human epi...          F
# ...                                                  ...        ...
# 18100  Selectivity interaction (TR-FRET binding assay...          B
# 18101  Selectivity interaction (Kinase panel (radiome...          B
# 18102  Selectivity interaction (Kinase panel (Enzymat...          B
# 18103  Selectivity interaction (Kinase panel (33PanQi...          B
# 18104  Selectivity interaction (Radiometric kinase as...          B
#
#       assay_variant_accession assay_variant_mutation bao_endpoint  ...  \
# 0                         NaN                    NaN  BAO_0000190  ...
# 1                         NaN                    NaN  BAO_0000190  ...
# 2                         NaN                    NaN  BAO_0000190  ...
# 3                         NaN                    NaN  BAO_0000190  ...
# 4                         NaN                    NaN  BAO_0000190  ...
# ...                       ...                    ...          ...  ...
# 18100                     NaN                    NaN  BAO_0000190  ...
# 18101                     NaN                    NaN  BAO_0000190  ...
# 18102                     NaN                    NaN  BAO_0000190  ...
# 18103                     NaN                    NaN  BAO_0000190  ...
# 18104                     NaN                    NaN  BAO_0000190  ...
#
#       target_organism                        target_pref_name target_tax_id  \
# 0        Homo sapiens  Epidermal growth factor receptor erbB1          9606
# 1        Homo sapiens  Epidermal growth factor receptor erbB1          9606
# 2        Homo sapiens  Epidermal growth factor receptor erbB1          9606
# 3        Homo sapiens  Epidermal growth factor receptor erbB1          9606
# 4        Homo sapiens  Epidermal growth factor receptor erbB1          9606
# ...               ...                                     ...           ...
# 18100    Homo sapiens  Epidermal growth factor receptor erbB1          9606
# 18101    Homo sapiens  Epidermal growth factor receptor erbB1          9606
# 18102    Homo sapiens  Epidermal growth factor receptor erbB1          9606
# 18103    Homo sapiens  Epidermal growth factor receptor erbB1          9606
# 18104    Homo sapiens  Epidermal growth factor receptor erbB1          9606
#
#       text_value toid  type units    uo_units upper_value      value
# 0            NaN  NaN  IC50    uM  UO_0000065         NaN      0.041
# 1            NaN  NaN  IC50    uM  UO_0000065         NaN      0.300
# 2            NaN  NaN  IC50    uM  UO_0000065         NaN      7.820
# 3            NaN  NaN  IC50    uM  UO_0000065         NaN      0.170
# 4            NaN  NaN  IC50    uM  UO_0000065         NaN      0.040
# ...          ...  ...   ...   ...         ...         ...        ...
# 18100        NaN  NaN  IC50    uM  UO_0000065         NaN     10.000
# 18101        NaN  NaN  IC50    nM  UO_0000065         NaN  50000.000
# 18102        NaN  NaN  IC50    uM  UO_0000065         NaN     10.000
# 18103        NaN  NaN  IC50    uM  UO_0000065         NaN     10.000
# 18104        NaN  NaN  IC50    uM  UO_0000065         NaN     10.000
#
# [16718 rows x 46 columns]

# %% [markdown]
# Apparently, for this dataset there is no missing data. But we can use the above code cell for bioactivity data of other target protein.

# %% [markdown]
# ## **Data pre-processing of the bioactivity data**

# %% [markdown]
# ### **Labeling compounds as either being active, inactive or intermediate**
# The bioactivity data is in the IC50 unit. Compounds having values of less than 1000 nM will be considered to be **active** while those greater than 10,000 nM will be considered to be **inactive**. As for those values in between 1,000 and 10,000 nM will be referred to as **intermediate**.

# %%
bioactivity_class = []
for i in df2.standard_value:
  if float(i) >= 10000:
    bioactivity_class.append("inactive")
  elif float(i) <= 1000:
    bioactivity_class.append("active")
  else:
    bioactivity_class.append("intermediate")

# %% [markdown]
# ### **Iterate the *molecule_chembl_id* to a list**

# %%
mol_cid = []
for i in df2.molecule_chembl_id:
  mol_cid.append(i)

# %% [markdown]
# ### **Iterate *canonical_smiles* to a list**

# %%
canonical_smiles = []
for i in df2.canonical_smiles:
  canonical_smiles.append(i)

# %% [markdown]
# ### **Iterate *standard_value* to a list**

# %%
standard_value = []
for i in df2.standard_value:
  standard_value.append(i)

# %% [markdown]
# ### **Combine the 4 lists into a dataframe**

# %%
data_tuples = list(zip(mol_cid, canonical_smiles, bioactivity_class, standard_value))
df3 = pd.DataFrame( data_tuples,  columns=['molecule_chembl_id', 'canonical_smiles', 'bioactivity_class', 'standard_value'])

# %%
df3
# Out:
#       molecule_chembl_id                                   canonical_smiles  \
# 0            CHEMBL68920  Cc1cc(C)c(/C=C2\C(=O)Nc3ncnc(Nc4ccc(F)c(Cl)c4)...
# 1            CHEMBL68920  Cc1cc(C)c(/C=C2\C(=O)Nc3ncnc(Nc4ccc(F)c(Cl)c4)...
# 2            CHEMBL68920  Cc1cc(C)c(/C=C2\C(=O)Nc3ncnc(Nc4ccc(F)c(Cl)c4)...
# 3            CHEMBL69960  Cc1cc(C(=O)N2CCOCC2)[nH]c1/C=C1\C(=O)Nc2ncnc(N...
# 4            CHEMBL69960  Cc1cc(C(=O)N2CCOCC2)[nH]c1/C=C1\C(=O)Nc2ncnc(N...
# ...                  ...                                                ...
# 16713      CHEMBL3622821  CC[C@@H]1CN(C(=O)NCC(F)(F)F)C[C@@H]1c1cnc2cnc3...
# 16714       CHEMBL209148  COc1cc(C)c(Sc2cnc(NC(=O)c3ccc(CNC(C)C(C)(C)C)c...
# 16715      CHEMBL1852688  CCN1CCN(c2ccc(Nc3cc(N(C)C(=O)Nc4c(Cl)c(OC)cc(O...
# 16716      CHEMBL3643413  CCC(=O)N1CC[C@H](Nc2ncnc3c2CN(c2cnc(OC)c(C(F)(...
# 16717       CHEMBL189963  CC(=O)c1c(C)c2cnc(Nc3ccc(N4CCNCC4)cn3)nc2n(C2C...
#
#       bioactivity_class  standard_value
# 0                active            41.0
# 1                active           300.0
# 2          intermediate          7820.0
# 3                active           170.0
# 4                active            40.0
# ...                 ...             ...
# 16713          inactive         10000.0
# 16714          inactive         50000.0
# 16715          inactive         10000.0
# 16716          inactive         10000.0
# 16717          inactive         10000.0
#
# [16718 rows x 4 columns]

# %% [markdown]
# ### **Alternative method**

# %%
selection = ['molecule_chembl_id', 'canonical_smiles', 'standard_value']
df3 = df2[selection]
df3
# Out:
#       molecule_chembl_id                                   canonical_smiles  \
# 0            CHEMBL68920  Cc1cc(C)c(/C=C2\C(=O)Nc3ncnc(Nc4ccc(F)c(Cl)c4)...
# 1            CHEMBL68920  Cc1cc(C)c(/C=C2\C(=O)Nc3ncnc(Nc4ccc(F)c(Cl)c4)...
# 2            CHEMBL68920  Cc1cc(C)c(/C=C2\C(=O)Nc3ncnc(Nc4ccc(F)c(Cl)c4)...
# 3            CHEMBL69960  Cc1cc(C(=O)N2CCOCC2)[nH]c1/C=C1\C(=O)Nc2ncnc(N...
# 4            CHEMBL69960  Cc1cc(C(=O)N2CCOCC2)[nH]c1/C=C1\C(=O)Nc2ncnc(N...
# ...                  ...                                                ...
# 18100      CHEMBL3622821  CC[C@@H]1CN(C(=O)NCC(F)(F)F)C[C@@H]1c1cnc2cnc3...
# 18101       CHEMBL209148  COc1cc(C)c(Sc2cnc(NC(=O)c3ccc(CNC(C)C(C)(C)C)c...
# 18102      CHEMBL1852688  CCN1CCN(c2ccc(Nc3cc(N(C)C(=O)Nc4c(Cl)c(OC)cc(O...
# 18103      CHEMBL3643413  CCC(=O)N1CC[C@H](Nc2ncnc3c2CN(c2cnc(OC)c(C(F)(...
# 18104       CHEMBL189963  CC(=O)c1c(C)c2cnc(Nc3ccc(N4CCNCC4)cn3)nc2n(C2C...
#
#       standard_value
# 0               41.0
# 1              300.0
# 2             7820.0
# 3              170.0
# 4               40.0
# ...              ...
# 18100        10000.0
# 18101        50000.0
# 18102        10000.0
# 18103        10000.0
# 18104        10000.0
#
# [16718 rows x 3 columns]

# %%
pd.concat([df3,pd.Series(bioactivity_class)], axis=1)
# Out:
#       molecule_chembl_id                                   canonical_smiles  \
# 0            CHEMBL68920  Cc1cc(C)c(/C=C2\C(=O)Nc3ncnc(Nc4ccc(F)c(Cl)c4)...
# 1            CHEMBL68920  Cc1cc(C)c(/C=C2\C(=O)Nc3ncnc(Nc4ccc(F)c(Cl)c4)...
# 2            CHEMBL68920  Cc1cc(C)c(/C=C2\C(=O)Nc3ncnc(Nc4ccc(F)c(Cl)c4)...
# 3            CHEMBL69960  Cc1cc(C(=O)N2CCOCC2)[nH]c1/C=C1\C(=O)Nc2ncnc(N...
# 4            CHEMBL69960  Cc1cc(C(=O)N2CCOCC2)[nH]c1/C=C1\C(=O)Nc2ncnc(N...
# ...                  ...                                                ...
# 16424                NaN                                                NaN
# 16601                NaN                                                NaN
# 16628                NaN                                                NaN
# 16655                NaN                                                NaN
# 16682                NaN                                                NaN
#
#       standard_value             0
# 0               41.0        active
# 1              300.0        active
# 2             7820.0  intermediate
# 3              170.0        active
# 4               40.0        active
# ...              ...           ...
# 16424            NaN  intermediate
# 16601            NaN        active
# 16628            NaN        active
# 16655            NaN        active
# 16682            NaN        active
#
# [18103 rows x 4 columns]

# %% [markdown]
# Saves dataframe to CSV file

# %%
df3.to_csv('bioactivity_preprocessed_data.csv', index=False)

# %%
! ls -l
# Out:
# total 12564
# -rw-r--r-- 1 root root 11443244 Jan  5 22:37 bioactivity_data.csv
# -rw-r--r-- 1 root root  1410204 Jan  5 22:41 bioactivity_preprocessed_data.csv
# drwx------ 6 root root     4096 Jan  5 22:33 gdrive
# drwxr-xr-x 1 root root     4096 Jan  2 14:19 sample_data

# %% [markdown]
# Let's copy to the Google Drive

# %%
! cp bioactivity_preprocessed_data.csv "/content/gdrive/My Drive/ScienceFair/DrugDesign/Colab"

# %%
! ls "/content/gdrive/My Drive/ScienceFair/DrugDesign/Colab"
# Out:
# bioactivity_data.csv  bioactivity_data_preprocessed.csv  bioactivity_preprocessed_data.csv

# %% [markdown]
# ---
